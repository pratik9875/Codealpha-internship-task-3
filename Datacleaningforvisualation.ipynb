# %%
import pandas as pd
data=pd.read_csv("books_dataset.csv")
df=pd.DataFrame(data)
print(df.head())
df.isnull().sum()
df['price']=df['price'].str.replace('Â£','')
df['price']=pd.to_numeric(df['price'],errors='coerce')
print(df['price'])
df['description']=df['description'].fillna('No Description available')
print(df['description'])

df.to_csv("cleaned_books.csv",index='False')
print("Cleaning completed. File saved as cleaned_books_dataset.csv")
print(df.head())
# Out:
#                                    title  \
# 0                   A Light in the Attic
# 1                     Tipping the Velvet
# 2                             Soumission
# 3                          Sharp Objects
# 4  Sapiens: A Brief History of Humankind
#
#                                             page_url    price rating  \
# 0  http://books.toscrape.com/a-light-in-the-attic...  Â£51.77  Three
# 1  http://books.toscrape.com/tipping-the-velvet_9...  Â£53.74    One
# 2  http://books.toscrape.com/soumission_998/index...  Â£50.10    One
# 3  http://books.toscrape.com/sharp-objects_997/in...  Â£47.82   Four
# 4  http://books.toscrape.com/sapiens-a-brief-hist...  Â£54.23   Five
#
#   availability  description
# 0     In stock          NaN
# 1     In stock          NaN
# 2     In stock          NaN
# 3     In stock          NaN
# 4     In stock          NaN
# 0     51.77
# 1     53.74
# 2     50.10
# 3     47.82
# 4     54.23
#       ...
# 95    19.92
# 96    40.11
# 97    53.90
# ...

# %%
plt.figure(figsize=(8,5))
plt.hist(df['price'])
plt.title("Price Distribution of Books")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,5))
df['rating'].value_counts().plot(kind='bar',color='red')
plt.title("Book Ratings Count")
plt.xlabel("Rating")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.boxplot(df['price'])
plt.title('Price using boxplot')
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %%
plt.figure(figsize=(8,5))
plt.scatter(df.index,df['price'])
plt.title("Scatter plot betweeen index and price")
plt.ylabel("price")
plt.xlabel("index")
plt.show()

# %%
sns.histplot(df['price'],kde=True)
plt.title("Price Distribution (Seaborn)")
plt.show()

# %%
sns.countplot(x='rating', data=df)
plt.title("Rating Count (Seaborn)")
plt.show()

# %%
sns.boxplot(df['price'])
plt.title('boxplot using seaborn')
plt.show()

# %%
sns.scatterplot(x=df.index, y=df['price'])
plt.title("Price Scatter Plot (Seaborn)")
plt.show()
